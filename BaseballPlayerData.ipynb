# %% [markdown]
# # Data Analysis in Baseball Data
# ### My Questions
# 1. What is the relationship between different performance metrics? Do any have a strong negative or positive relationship?
#     - team winning vs self-big. - Can one man lead whole team? vs teamwork is important
#     - college player gets better salary? -
#     - home play tend to lead
#     - highest salries players do well on especially Series or as good as Series.
#     -
# 2. What are the characteristics of baseball players with the highest salaries?
#     - which role is highest salaries? hitter?
#     * Load Data from CSVs
#     * Fix Data Type
#     * Investigate Data
#     * Make Histogram
#     * Improve Plots and Sharing Findings

# %%
import pandas as pd
player_df = pd.read_csv("baseballdatabank-master/core/Master.csv")
player_df.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile     1984.0         8.0      16.0    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#         nameGiven weight height bats throws       debut   finalGame   retroID  \
# ...

# %%
salary_df = pd.read_csv("baseballdatabank-master/core/Salaries.csv")
salary_top5 = salary_df.sort(columns='salary', axis=0, ascending=False).head()
# Out:
# /home/jaemin/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
player_df.merge(salary_top5, on="playerID", how="right")[['nameFirst','nameLast','salary']]
# Out:
#   nameFirst   nameLast    salary
# 0   Clayton    Kershaw  32571000
# 1      Alex  Rodriguez  33000000
# 2      Alex  Rodriguez  33000000
# 3      Alex  Rodriguez  32000000
# 4      Alex  Rodriguez  30000000
